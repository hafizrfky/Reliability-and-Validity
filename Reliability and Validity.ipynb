# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
cols = ["q1im", "q2im", "q3im", "q4im", "q5im",
           "q6im", "q7im", "q8im", "q9im",
           "q10im"]
df = pd.read_spss("/Users/Apple/Downloads/STAFFSURVEY.sav",
                  usecols = cols )
df.head()
# Out:
#         q1im       q2im        q3im        q4im        q5im       q6im  \
# 0       very  extremely   extremely   extremely   extremely  extremely
# 1       very       very  not at all    slightly  moderately       very
# 2  extremely  extremely   extremely        very   extremely  extremely
# 3  extremely       very  moderately        very        very       very
# 4  extremely  extremely        very  moderately        very  extremely
#
#         q7im       q8im       q9im      q10im
# 0       very  extremely  extremely  extremely
# 1   slightly  extremely   slightly       very
# 2  extremely  extremely  extremely  extremely
# 3       very       very       very       very
# 4       very  extremely  extremely       very

# %% [markdown]
# # Mencari Modus

# %%
df['q1im'].mode()
# Out:
# 0    extremely
# Name: q1im, dtype: category
# Categories (5, object): [extremely, moderately, not at all, slightly, very]

# %%
df['q2im'].mode()
# Out:
# 0    extremely
# Name: q2im, dtype: category
# Categories (5, object): [extremely, moderately, not at all, slightly, very]

# %%
df['q3im'].mode()
# Out:
# 0    very
# Name: q3im, dtype: category
# Categories (5, object): [extremely, moderately, not at all, slightly, very]

# %%
df['q4im'].mode()
# Out:
# 0    extremely
# Name: q4im, dtype: category
# Categories (5, object): [extremely, moderately, not at all, slightly, very]

# %%
df['q5im'].mode()
# Out:
# 0    very
# Name: q5im, dtype: category
# Categories (5, object): [extremely, moderately, not at all, slightly, very]

# %%
df['q6im'].mode()
# Out:
# 0    very
# Name: q6im, dtype: category
# Categories (5, object): [extremely, moderately, not at all, slightly, very]

# %%
df['q7im'].mode()
# Out:
# 0    very
# Name: q7im, dtype: category
# Categories (5, object): [extremely, moderately, not at all, slightly, very]

# %%
df['q8im'].mode()
# Out:
# 0    extremely
# Name: q8im, dtype: category
# Categories (5, object): [extremely, moderately, not at all, slightly, very]

# %%
df['q9im'].mode()
# Out:
# 0    extremely
# 1         very
# Name: q9im, dtype: category
# Categories (5, object): [extremely, moderately, not at all, slightly, very]

# %%
df['q10im'].mode()
# Out:
# 0    extremely
# Name: q10im, dtype: category
# Categories (5, object): [extremely, moderately, not at all, slightly, very]

# %% [markdown]
# # Mengubah NaN Menjadi Nilai Modus

# %%
df = df.fillna({"q1im": "extremely"})

# %%
df = df.fillna({"q2im": "extremely"})

# %%
df = df.fillna({"q3im": "very"})

# %%
df = df.fillna({"q4im": "extremely"})

# %%
df = df.fillna({"q5im": "very"})

# %%
df = df.fillna({"q6im": "very"})

# %%
df = df.fillna({"q7im": "very"})

# %%
df = df.fillna({"q8im": "extremely"})

# %%
df = df.fillna({"q9im": "extremely"})

# %%
df = df.fillna({"q10im": "extremely"})

# %% [markdown]
# # Data

# %%
pd.set_option('display.max_rows', df.shape[0]+1)
df
# Out:
#            q1im        q2im        q3im        q4im        q5im        q6im  \
# 0          very   extremely   extremely   extremely   extremely   extremely
# 1          very        very  not at all    slightly  moderately        very
# 2     extremely   extremely   extremely        very   extremely   extremely
# 3     extremely        very  moderately        very        very        very
# 4     extremely   extremely        very  moderately        very   extremely
# 5     extremely   extremely   extremely   extremely   extremely   extremely
# 6     extremely        very  moderately  moderately  not at all  moderately
# 7          very   extremely   extremely   extremely   extremely   extremely
# 8     extremely   extremely   extremely  moderately   extremely        very
# 9          very        very        very   extremely   extremely        very
# 10         very        very        very  moderately  moderately  moderately
# ...

# %%
df.shape
# Out:
# (536, 10)

# %%
df = df.astype('category')
df.dtypes
# Out:
# q1im     category
# q2im     category
# q3im     category
# q4im     category
# q5im     category
# q6im     category
# q7im     category
# q8im     category
# q9im     category
# q10im    category
# dtype: object

# %% [markdown]
# # Mengubah Categorical Menjadi Numerical

# %%
df['q1im'] = df['q1im'].cat.codes

# %%
df['q2im'] = df['q2im'].cat.codes

# %%
df['q3im'] = df['q3im'].cat.codes

# %%
df['q4im'] = df['q4im'].cat.codes

# %%
df['q5im'] = df['q5im'].cat.codes

# %%
df['q6im'] = df['q6im'].cat.codes

# %%
df['q7im'] = df['q7im'].cat.codes

# %%
df['q8im'] = df['q8im'].cat.codes

# %%
df['q9im'] = df['q9im'].cat.codes

# %%
df['q10im'] = df['q10im'].cat.codes

# %% [markdown]
# # Menghitung Validitas

# %%
df_corr = df.corr()

# %%
pearsoncorr = df.corr(method='pearson')

# %%
sb.heatmap(pearsoncorr, 
            xticklabels=pearsoncorr.columns,
            yticklabels=pearsoncorr.columns,
            cmap='RdBu_r',
            annot=True,
            linewidth=0.5)

# %% [markdown]
# ###### Dalam HeatMap diatas, dapat dilihat korelasi antar variabel dimana yang diatas 0,3 adalah Valid

# %% [markdown]
# # Menghitung Reliabilitas

# %%
N = df.shape[1]

# %%
def cronbach_alpha(df):
    rs = np.array([])
    for i, col in enumerate(df_corr.columns):
        sum_ = df_corr[col][i+1:].values
        rs = np.append(sum_, rs)
    mean_r = np.mean(rs)
    cronbach_alpha = (N * mean_r) / (1 + (N - 1) * mean_r)
    return cronbach_alpha

# %%
cronbach_alpha(df)
# Out:
# 0.7502766577594195

# %% [markdown]
# ###### Jika hasil cronbach_alpha > 0.6 maka dapat disimpulkan data tersebut reliabel
